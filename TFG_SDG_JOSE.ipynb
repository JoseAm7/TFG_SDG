# %% [markdown]
# <a href="https://colab.research.google.com/github/JoseAm7/TFG_SDG/blob/dev/TFG_SDG_JOSE.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

file_path = '/content/drive/MyDrive/Colab Notebooks/BBDD-Local.xlsx'

df = pd.read_excel(file_path,sheet_name='C_BBDD')


correlation_matrix = df.corr()

print(correlation_matrix)
# Out:
#      ID
# ID  1.0

# %%
df.describe
# Out:
# <bound method NDFrame.describe of             ID               Tipo            Categoría        Categoría.1  \
# 0      1165252       Extracciones  Extracción de datos                NaN
# 1      1165248       Extracciones  Extracción de datos                NaN
# 2      1165245     Gestión de KDE                  NaN                NaN
# 3      1165034       Herramientas                  NaN  Uso de QLIK SENSE
# 4      1164938       Herramientas                  NaN  Uso de QLIK SENSE
# ...        ...                ...                  ...                ...
# 16036   380375  Permisos Datapool                  NaN                NaN
# 16037   380373    Modelo de Datos                  NaN                NaN
# 16038   378538  Permisos Datapool                  NaN                NaN
# 16039   378533    Modelo de Datos                  NaN                NaN
# 16040   378317    Modelo de Datos                  NaN                NaN
#
# ...

# %%
#Cambiamos el nombre de algunas columnas para poder trabajar con ellas mas adelante
df.rename(columns={'Categoría Final':' Categoría_Final'}, inplace=True)
df.rename(columns={'Fecha de creación': 'Fecha_de_creacion'}, inplace=True)
df.rename(columns={'Fecha solución propuesta': 'Categoria_Final'}, inplace=True)
df.rename(columns={'Fecha de modificación': 'Fecha_de_modificacion'}, inplace=True)

#El inplace = True hace que las modificaciones se hagan sobr el df actual en vez de crear un 
#nuevo df con las nuevas modificaciones

# %%
df.ID.plot();

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df.Fecha_de_modificacion.plot(x='Month',y='Fecha_de_modificacion')

# %%
import datetime as dt

# %%
df['date']= pd.to_datetime(df.Fecha_de_modificacion)

# %%
df['Year'] = pd.DatetimeIndex(df.date).year
df['Month'] = pd.DatetimeIndex(df.date).month
df['Day'] =pd.DatetimeIndex(df.date).day
df['weekday'] = pd.DatetimeIndex(df.date).weekday

# %%
df.describe()
# Out:
#                  ID          Year         Month           Day       weekday
# count  1.604100e+04  16041.000000  16041.000000  16041.000000  16041.000000
# mean   8.369551e+05   2019.889471      6.868898     15.505081      1.932361
# std    2.238160e+05      1.770657      3.371356      8.976694      1.371459
# min    3.783170e+05   2016.000000      1.000000      1.000000      0.000000
# 25%    6.351280e+05   2018.000000      4.000000      8.000000      1.000000
# 50%    8.832230e+05   2020.000000      7.000000     15.000000      2.000000
# 75%    1.028164e+06   2021.000000     10.000000     23.000000      3.000000
# max    1.165252e+06   2022.000000     12.000000     31.000000      6.000000

# %%
df['year'] = "2016"

# %%
df = df.drop(columns=['year'], axis=1)

# %%
df_2016 = df[df.Year == 2016]

# %%
df_2016.set_index('date', inplace=True)

# %%
df_2017 = df[df.Year == 2017]
df_2018 = df[df.Year == 2018]
df_2019 = df[df.Year == 2019]
df_2020 = df[df.Year == 2020]
df_2021 = df[df.Year == 2021]
df_2022 = df[df.Year == 2022]

# %%
df_2017.set_index('Month', drop=False, inplace=True);
df_2018.set_index('Month',drop=False, inplace=True)
df_2019.set_index('Month',drop=False, inplace=True)
df_2020.set_index('Month', drop=False,inplace=True)
df_2021.set_index('Month',drop=False, inplace=True)
df_2022.set_index('Month', drop=False,inplace=True)

# %%
df
# Out:
#             ID               Tipo            Categoría        Categoría.1  \
# 0      1165252       Extracciones  Extracción de datos                NaN
# 1      1165248       Extracciones  Extracción de datos                NaN
# 2      1165245     Gestión de KDE                  NaN                NaN
# 3      1165034       Herramientas                  NaN  Uso de QLIK SENSE
# 4      1164938       Herramientas                  NaN  Uso de QLIK SENSE
# ...        ...                ...                  ...                ...
# 16036   380375  Permisos Datapool                  NaN                NaN
# 16037   380373    Modelo de Datos                  NaN                NaN
# 16038   378538  Permisos Datapool                  NaN                NaN
# 16039   378533    Modelo de Datos                  NaN                NaN
# 16040   378317    Modelo de Datos                  NaN                NaN
#
#                              Categoría.2                    Categoría_Final  \
# ...

# %%
plt.plot(df_2017['Month'],df_2017['ID'])

# %%
df_2017
# Out:
#            ID               Tipo                          Categoría  \
# Month
# 12     541701       Herramientas                                NaN
# 12     541334  Permisos Datapool                                NaN
# 12     541285       Herramientas                                NaN
# 12     540481  Permisos Datapool                                NaN
# 12     539712    Modelo de Datos                                NaN
# ...       ...                ...                                ...
# 4      388288    Modelo de Datos                                NaN
# 1      382741       Extracciones  Categoria_Extracciones.literal.l4
# 1      381848       Extracciones  Categoria_Extracciones.literal.l4
# 1      380381       Extracciones  Categoria_Extracciones.literal.l2
# 1      380378       Extracciones  Categoria_Extracciones.literal.l4
#
#              Categoría.1                        Categoría.2  \
# Month
# 12     Uso de QLIK SENSE                                NaN
# ...

# %%
df.Year.plot(kind='bar')

# %%
df['ID']
# Out:
# 0        1165252
# 1        1165248
# 2        1165245
# 3        1165034
# 4        1164938
#           ...
# 16036     380375
# 16037     380373
# 16038     378538
# 16039     378533
# 16040     378317
# Name: ID, Length: 16041, dtype: int64

# %%
df.head()
# Out:
#         ID            Tipo            Categoría        Categoría.1  \
# 0  1165252    Extracciones  Extracción de datos                NaN
# 1  1165248    Extracciones  Extracción de datos                NaN
# 2  1165245  Gestión de KDE                  NaN                NaN
# 3  1165034    Herramientas                  NaN  Uso de QLIK SENSE
# 4  1164938    Herramientas                  NaN  Uso de QLIK SENSE
#
#   Categoría.2      Categoría Final   Fecha de creación  \
# 0         NaN  Extracción de datos 2022-12-30 14:32:00
# 1         NaN  Extracción de datos 2022-12-30 14:23:00
# 2         NaN       Gestión de KDE 2022-12-30 14:11:00
# 3         NaN    Uso de QLIK SENSE 2022-12-30 01:09:00
# 4         NaN    Uso de QLIK SENSE 2022-12-29 17:17:00
#
#   Fecha solución propuesta    Subcategoría Fecha de modificación
# 0                      NaT             NaN   2022-12-30 15:19:00
# 1                      NaT             NaN   2022-12-30 15:18:00
# ...

# %%
df.shape
# Out:
# (16041, 10)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16041 entries, 0 to 16040
# Data columns (total 10 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   ID                        16041 non-null  int64
#  1   Tipo                      16041 non-null  object
#  2   Categoría                 1147 non-null   object
#  3   Categoría.1               7555 non-null   object
#  4   Categoría.2               3392 non-null   object
#  5   Categoría Final           16041 non-null  object
#  6   Fecha de creación         16041 non-null  datetime64[ns]
#  7   Fecha solución propuesta  14606 non-null  datetime64[ns]
#  8   Subcategoría              7555 non-null   object
#  9   Fecha de modificación     16041 non-null  datetime64[ns]
# dtypes: datetime64[ns](3), int64(1), object(6)
# memory usage: 1.2+ MB

# %%
df.describe(include='all')
# Out:
# <ipython-input-8-174ba9bf1a5c>:1: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   df.describe(include='all')
#                   ID          Tipo            Categoría        Categoría.1  \
# count   1.604100e+04         16041                 1147               7555
# unique           NaN             7                    3                  6
# top              NaN  Herramientas  Extracción de datos  Uso de QLIK SENSE
# freq             NaN          7555                  774               3950
# first            NaN           NaN                  NaN                NaN
# last             NaN           NaN                  NaN                NaN
# mean    8.369551e+05           NaN                  NaN                NaN
# ...

# %%
df.describe()
# Out:
#                  ID
# count  1.604100e+04
# mean   8.369551e+05
# std    2.238160e+05
# min    3.783170e+05
# 25%    6.351280e+05
# 50%    8.832230e+05
# 75%    1.028164e+06
# max    1.165252e+06

# %%
pip install jovian
# Out:
#   File "<ipython-input-6-75a753c9e43f>", line 1
#     pip install jovian
#         ^
# SyntaxError: invalid syntax

# %%
import jovian

# %%
def vacation(City, Return_flight_money, hotel_per_day_money, days, weekly_rental_car_money):
  """Calculate which is the cheapest city to go on vacation"""
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-cadf3e4543e1> in <module>
# ----> 1 type(df.ID)
#
# NameError: name 'df' is not defined

# %%
from urllib.request import urlretrieve

# %%
urlretrieve('https://www.kaggle.com/datasets/thedevastator/domestic-food-prices-after-covid-19?select=dom_clean_data.csv', 'food_prices.csv')
# Out:
# ('food_prices.csv', <http.client.HTTPMessage at 0x7f0b2995a250>)

# %%
california_df = pd.read_csv('sample_data/california_housing_test.csv')

# %%
california_df
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0       -122.05     37.37                27.0       3885.0           661.0
# 1       -118.30     34.26                43.0       1510.0           310.0
# 2       -117.81     33.78                27.0       3589.0           507.0
# 3       -118.36     33.82                28.0         67.0            15.0
# 4       -119.67     36.33                19.0       1241.0           244.0
# ...         ...       ...                 ...          ...             ...
# 2995    -119.86     34.42                23.0       1450.0           642.0
# 2996    -118.14     34.06                27.0       5257.0          1082.0
# 2997    -119.70     36.30                10.0        956.0           201.0
# 2998    -117.12     34.10                40.0         96.0            14.0
# 2999    -119.63     34.42                42.0       1765.0           263.0
#
#       population  households  median_income  median_house_value
# ...

# %%
plt.plot(california_df['median_house_value'],california_df['housing_median_age']);

# %%
sample_data/california_housing_test.csv
